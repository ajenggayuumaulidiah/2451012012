# %%
print('Dia berkata:"Pergilah!"')
# Out:
# Dia berkata:"Pergilah!"

# %%
print ("Aku menimpali: \"Apakahkau ingin aku 'angkat kaki'?!\"")
# Out:
# Aku menimpali: "Apakahkau ingin aku 'angkat kaki'?!"

# %%
print (" \\(^_^) / (\\-_-/)")
# Out:
#  \(^_^) / (\-_-/)
