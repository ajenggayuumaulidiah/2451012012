# %% [markdown]
# *   Nama: Ajeng Ayu Maulidiah
# *   Npm: 2451012012

# %%
nama = "Ajeng Ayu Maulidiah"
asal= "Bandar Lampung"

# %%
print (nama = asal)

# %%
print("halo, nama saya",nama)
# Out:
# halo, nama saya Ajeng Ayu Maulidiah

# %%
print("halo, nama saya", nama, "asal saya dari",asal)
# Out:
# halo, nama saya Ajeng Ayu Maulidiah asal saya dari Bandar Lampung

# %%
data_lengkap = nama + asal

# %%
print (asal)
# Out:
# Bandar Lampung

# %% [markdown]
# **string + non string**

# %%
asal_kota= "Bandar Lampung"
kode_pos = 35144

asal_kota_kode_pos = asal_kota + str(kode_pos)
print (asal_kota_kode_pos)
# Out:
# Bandar Lampung35144

# %%
asal_kota_x3 = asal_kota * 3
print (asal_kota_x3)
# Out:
# Bandar LampungBandar LampungBandar Lampung
